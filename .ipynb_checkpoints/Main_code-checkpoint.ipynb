# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import re
from src import myfunctions
import statsmodels.api as sm
from scipy import signal
import scipy as sp
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# Data sources:
#
# - Electricity production by source - Our World in Data
# https://ourworldindata.org/energy-mix
#
# - CO2 emmissions by country - Our World in Data
# https://ourworldindata.org/co2-and-other-greenhouse-gas-emissions
#
# - Solar Photovoltaic potential by country - The World Bank
# https://datacatalog.worldbank.org/search/dataset/0038379

# %%
# Read data from csv
df_el_prod=pd.read_csv("./input/electricity-prod-source.csv", encoding='ISO-8859-1')
df_co2=pd.read_csv("./input/co2-data.csv", encoding='ISO-8859-1')
df_solar=pd.read_csv("./input/Solar_radiation.csv", encoding='ISO-8859-1')

# %%
# Get clean series
df_series=myfunctions.cleanseries(df_el_prod,df_co2)

# %%
plt.figure(figsize = (12,8))
sns.lineplot(data=df_series[df_series['Country'].isin(['China','United States','Russia','Japan','Iran','Spain','Germany'])],x='Year',y='co2', hue='Country')
plt.title('Development of largest poluters (Million Tons per year)')
# Out:
# Text(0.5, 1.0, 'Development of largest poluters (Million Tons per year)')

# %%
plt.figure(figsize = (12,8))
sns.lineplot(data=df_series[df_series['Country'].isin(['China','United States','Russia','Japan','Iran','Spain','Germany'])],x='Year',y='co2_per_capita', hue='Country')
plt.title('CO2 polution tons per capita per year')
# Out:
# Text(0.5, 1.0, 'CO2 polution tons per capita per year')

# %%
country=input('Please select a country to plot: ')
# Out:
# Please select a country to plot: Saudi Arabia

# %%
columns=['Coal','Gas','Oil','Nuclear','Bioenergy','Hydro','Solar','Wind']
ax=df_series.loc[df_series['Country']==country].plot(x='Year', y=columns, kind='area', stacked=True, figsize=(12,8))
ax.set_ylabel(f'Energy production by source TWh in {country}')
ax2=df_series.loc[df_series['Country']==country].plot(x='Year', y='co2' ,kind='line', color='k', secondary_y=True, figsize=(12,8), ax=ax)
ax2.set_ylabel(f'CO2 M tons per year in {country}')
plt.title(f'Electricity production by source and CO2 in {country}')
plt.show()

ax=df_series.loc[df_series['Country']==country].plot(x='Year', y='gdp_per_capita', kind='line', figsize=(12,8))
ax.set_ylabel('GDP per capita $')
ax2=df_series.loc[df_series['Country']==country].plot(x='Year', y='co2_per_capita' ,kind='line', color='r', secondary_y=True, figsize=(12,8), ax=ax)
ax2.set_ylabel('CO2 per capita tons per year')
plt.title(f'GDP and CO2 development per capita in {country}')
plt.show()

# %%
df_poluters=myfunctions.getstatic(df_series,df_solar,2019)

# %%
df_poluters.sort_values('co2_per_capita',ascending=False, inplace=True)
ax=df_poluters[:40].plot(x='Country', y='co2_per_capita', kind='bar', figsize=(15,5), alpha=0.8)
ax.set_ylabel('tons per capita')
ax2=df_poluters[:40].plot(x='Country', y='P solar potential (kWh/day)', kind='bar', alpha=0.2, color='r', secondary_y=True, figsize=(15,5), ax=ax)
ax2.set_ylabel('Practical solar potential (kWh/day) long term average')
ax.axhline(df_poluters['co2_per_capita'].mean(), color='b')
plt.title('CO2 emmissions in tons per capita and practical solar potential per country')


df_poluters.sort_values('Electricity tariffs\n(US cent/kWh)',ascending=False, inplace=True)
ax=df_poluters[:40].plot(x='Country', y='Electricity tariffs\n(US cent/kWh)', kind='bar', alpha=0.8, figsize=(15,5))
ax.set_ylabel('Electricity tariffs (US cent/kWh)')
ax2=df_poluters[:40].plot(x='Country', y='P solar potential (kWh/day)', kind='bar', color='r',secondary_y=True, figsize=(15,5), alpha=0.25,ax=ax)
ax2.set_ylabel('Solar potential kWh/day/m2')
ax.axhline(df_poluters['Electricity tariffs\n(US cent/kWh)'].mean(), color='b')
plt.title('Solar potential and electricity tariffs per country')
# ask Fer how to add a third Y axis

df_poluters['$ Potential']=df_poluters['P solar potential (kWh/day)']*df_poluters['Electricity tariffs\n(US cent/kWh)']*365/100
df_poluters.sort_values('$ Potential',ascending=False, inplace=True)
ax=df_poluters[:30].plot(x='Country', y='$ Potential', kind='bar', figsize=(15,5))
ax.set_ylabel('Potential $ per year from 1m2')
ax.axhline(df_poluters['$ Potential'].mean())
plt.title('Monetary potential in $ from one square meter per year per country')
# Out:
# Text(0.5, 1.0, 'Monetary potential in $ from one square meter per year per country')

# %% [markdown]
# ### Web scraping

# %% [markdown]
# Now look in Wikipedia for solar manufacturers that you would contact with this proposition

# %%
import requests
from bs4 import BeautifulSoup as BS

# %%
url='https://en.wikipedia.org/wiki/List_of_photovoltaics_companies'

# %%
df_comp_full=myfunctions.scrape(url)
df_comp_full
# Out:
#                              Company                Type  \
# 1                             Yingli              Public
# 1              Vikram Solar Pvt. Ltd     Limited company
# 1                            Suntech              Public
# 1                           SunPower              Public
# 1                         SolarWorld  Aktiengesellschaft
# 1                    SolarPark Korea                 NaN
# 1                              Sharp              Public
# 1                          Panasonic              Public
# 1       Renewable Energy Corporation              Public
# 1                            Q-Cells                 NaN
# 1                    Neo Solar Power              Public
# 1                             Motech              Public
# 1                   Mitsubishi Heavy             Private
# 1                Mitsubishi Electric             Private
# 1                            Kyocera              Public
# 1                  JA Solar Holdings              Public
# 1                           Isofoton             Private
# 1                   Morgan Solar Inc             Private
# 1            Evergreen Solar[Note 3]              Public
# 1                           DelSolar              Public
# 1                            Conergy     Limited company
# 1                           BP Solar          Subsidiary
# 1                              Bosch              Public
# 1                     SunPower Corp.              Public
# 1                       Yingli Green              Public
# 1  GCL System Integration Technology             Limited
# 1                        First Solar              Public
# 1                     Hanwha Q CELLS                 NaN
# 1                     Canadian Solar              Public
# 1                        LONGi Solar                 NaN
# 1                           JA Solar              Public
# 1                        Jinko Solar              Public
# 1                              Jinko              Public
#
#                                             Industry Founded  \
# 1                                       solar energy    1998
# 1                                       Solar energy    2006
# 1                                      Photovoltaics    2001
# 1                                   Renewable energy    1985
# 1                                      Photovoltaics    1975
# 1                    Renewable Energy, Photovoltaics    2008
# 1                               Consumer electronics    1912
# 1                                       Conglomerate    1918
# 1                                       Solar energy    1996
# 1                                      Photovoltaics    1999
# 1  Solar Photovoltaics, Photovoltaics, Optoelectr...    2005
# 1               Solar photovoltaics, Optoelectronics    1981
# 1  Automotive Chemical Electronics Food Financial...    1870
# 1  Automotive Chemical Electronics Food Financial...    1870
# 1                                        Electronics    1959
# 1                                      Semiconductor    2005
# 1                         Photovoltaic, Solar Energy    1981
# 1                      Solar PowerSustainable Energy    2007
# 1                                   Renewable Energy
# 1  Solar cell, solar module, and Photovoltaic system    2004
# 1                                   Renewable energy    2000
# 1                                       Solar energy    1981
# 1                  Renewable Energies, Photovoltaics    1997
# 1                                   Renewable energy    1985
# 1                                       solar energy    1998
# 1  IndustrialsIndustrial engineeringNew energy ma...    1996
# 1                                      Photovoltaics    1999
# 1                                      Photovoltaics    1999
# 1           Renewable energy, Photovoltaics industry    2001
# 1                                      Photovoltaics    2000
# 1                                      Semiconductor    2005
# 1                                      Photovoltaics    2006
# 1                                      Photovoltaics    2006
#
#                                              Website  \
# 1              Yingli Green Energy site (in English)
# 1                                www.vikramsolar.com
# 1                             www.suntech-power.com/
# 1                                       sunpower.com
# 1                                 www.solarworld.com
# 1                                                [1]
# 1                     global.sharp sharpconsumer.com
# 1  holdings.panasonic (Corporate) panasonic.com (...
# 1                                   www.recgroup.com
# 1                                        q-cells.com
# 1                                        www.nsp.com
# 1  motech.com.tw（Chinese） motechsolar.com（English...
# 1                                     mitsubishi.com
# 1                                     mitsubishi.com
# 1                                 global.kyocera.com
# 1                                    www.JASolar.com
# 1                                   www.isofoton.com
# 1                                    morgansolar.com
# 1                             www.evergreensolar.com
# 1                          http://www.delsolarpv.com
# 1                                    www.conergy.com
# 1                                    www.bpsolar.com
# 1                           www.bosch-solarenergy.de
# 1                                       sunpower.com
# 1              Yingli Green Energy site (in English)
# 1                                www.gcl-poly.com.hk
# 1                                 www.firstsolar.com
# 1                                        q-cells.com
# 1                              www.canadiansolar.com
# 1                               en.longi-silicon.com
# 1                                    www.JASolar.com
# 1                          http://www.jinkosolar.com
# 1                          http://www.jinkosolar.com
#
#                                         Headquarters Number of employees  \
# 1  Baoding, Hebei province, People's Republic of ...               14533
# 1  "The Chambers", 8th Floor, 1865, Rajdanga Main...                 NaN
# 1                               Wuxi, Jiangsu, China                 NaN
# 1                         San Jose, California, U.S.                3660
# 1                                      Bonn, Germany                3034
# 1                                 Wanju, South Korea                 300
# 1            Sakai-ku Sakai, Osaka Prefecture, Japan               52876
# 1  Kadoma, Osaka, Japan.mw-parser-output .geo-def...              279385
# 1              20 Tuas South Avenue 14, Singapore[2]                4200
# 1                                 Seoul, South Korea                8500
# 1                                    Hsinchu, Taiwan                2400
# 1                                     Tainan, Taiwan                3500
# 1                                       Tokyo, Japan                 NaN
# 1                                       Tokyo, Japan                 NaN
# 1                                       Kyoto, Japan               70153
# 1                Beijing, People's Republic of China                1465
# 1                       Málaga, Spain, Madrid, Spain                1142
# 1                           Toronto, Ontario, Canada                  30
# 1          Marlborough, Massachusetts; United States                 NaN
# 1                                    Hsinchu, Taiwan                 810
# 1                    Fuji Xerox Towers, Singapore[2]                 NaN
# 1                                      Madrid, Spain                 NaN
# 1                                    Erfurt, Germany                1517
# 1                         San Jose, California, U.S.                3660
# 1  Baoding, Hebei province, People's Republic of ...               14533
# 1                          Hong Kong, Cayman Islands                 NaN
# 1                               Tempe, Arizona, U.S.                6400
# 1                                 Seoul, South Korea                8500
# 1                            Guelph, Ontario, Canada               13478
# 1                              Xi'an, Shaanxi, China                 NaN
# 1                Beijing, People's Republic of China                1465
# 1                                           Shanghai               13500
# 1                                           Shanghai               13500
#
#                                             Products  \
# 1                              photovoltaic products
# 1                                      Solar modules
# 1                                                NaN
# 1                                                NaN
# 1         Solar cells, wafers,PV modules and systems
# 1                               Photovoltaic modules
# 1  Televisions, audiovisual, home appliances, inf...
# 1  Artificial intelligenceAutomationConstructionE...
# 1    Polysilicon, wafers, solar cells, solar modules
# 1  Photovoltaic cellsSolar modulesSolar systemsLa...
# 1                  Solar Cell & Module &Solar System
# 1  Silicon solar cells, inverters, modules and so...
# 1  List Aircraft Automobiles Chemical substances ...
# 1  List Aircraft Automobiles Chemical substances ...
# 1  Semiconductor packagesIndustrial componentsAut...
# 1                           Photovoltaic solar cells
# 1                                                NaN
# 1          BIPVIn Situ IV Curve TracersOptical Films
# 1                                        Solar Cells
# 1                                                NaN
# 1                                                NaN
# 1                                                NaN
# 1                                                NaN
# 1                                                NaN
# 1